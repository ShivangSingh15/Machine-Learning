# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtcars = pd.read_csv("C:\\Users\\shiva\\Downloads\\Lesson 3 Practice\\Lesson 3 Practice\\mtcars.csv")

# %% [markdown]
# # 3.5
#
# Objective: Import the dataset, explore for dimensionality, and type and average value of the horsepower across all the cars. Also, identify a few of mostly correlated features, which would help
# in modification.
# ### Practise Project

# %%
mtcars.shape
# Out:
# (32, 12)

# %%
mtcars.shape
# Out:
# (32, 12)

# %%
type(mtcars)
# Out:
# pandas.core.frame.DataFrame

# %%
mtcars.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
mtcars['hp'].mean()
# Out:
# 146.6875

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
correlations = mtcars.corr()

# %%
sns.heatmap(data = correlations, square = True, cmap = "bwr")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3.10
# Problem Statement:
# Mtcars, the automobile company in the United States, has planned to rework on optimizing the horsepower of its cars as most of the customers’ feedback was centered around horsepower. However, while developing an ML model with respect to horsepower, the efficiency of the model was compromised. Irregularity might be one of the causes.
#
# Objective:
# Using the loaded dataset, perform different data exploration techniques and obtain their respective results.
# ### Practise Project

# %%
mtcars.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
mtcars.iloc[:,[0,4]]
# Out:
#                   model   hp
# 0             Mazda RX4  110
# 1         Mazda RX4 Wag  110
# 2            Datsun 710   93
# 3        Hornet 4 Drive  110
# 4     Hornet Sportabout  175
# 5               Valiant  105
# 6            Duster 360  245
# 7             Merc 240D   62
# 8              Merc 230   95
# 9              Merc 280  123
# 10            Merc 280C  123
# 11           Merc 450SE  180
# 12           Merc 450SL  180
# 13          Merc 450SLC  180
# 14   Cadillac Fleetwood  205
# 15  Lincoln Continental  215
# 16    Chrysler Imperial  230
# 17             Fiat 128   66
# 18          Honda Civic   52
# 19       Toyota Corolla   65
# 20        Toyota Corona   97
# 21     Dodge Challenger  150
# 22          AMC Javelin  150
# 23           Camaro Z28  245
# 24     Pontiac Firebird  175
# 25            Fiat X1-9   66
# 26        Porsche 914-2   91
# 27         Lotus Europa  113
# 28       Ford Pantera L  264
# 29         Ferrari Dino  175
# 30        Maserati Bora  335
# ...

# %%
mtcars['hp'].unique()
# Out:
# array([110,  93, 175, 105, 245,  62,  95, 123, 180, 205, 215, 230,  66,
#         52,  65,  97, 150,  91, 113, 264, 335, 109], dtype=int64)

# %%
mtcars['gear'].values
# Out:
# array([4, 4, 4, 3, 3, 3, 3, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 4, 4, 4, 3, 3,
#        3, 3, 3, 4, 5, 5, 5, 5, 5, 4], dtype=int64)

# %%
mtcars.mean()
# Out:
# C:\Users\shiva\AppData\Local\Temp/ipykernel_21464/665047178.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mtcars.mean()
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars.median()
# Out:
# C:\Users\shiva\AppData\Local\Temp/ipykernel_21464/3454397367.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mtcars.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
mtcars.mode(axis=0)# for calculating mode across columns {litt. opp.}
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %% [markdown]
# # 3.15
#
# Objective: Check for missing values and outliers within the horsepower column and remove them.
# ### Practise Project

# %%
mtcars.head(50)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars['hp'].isnull().any()
# Out:
# False

# %%
sns.boxplot(x=mtcars.hp)
# Out:
# <AxesSubplot:xlabel='hp'>

# %%
filter = mtcars['hp'].values<300
mtcars_outliers_removed = mtcars[filter]
mtcars_outliers_removed
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# # 3.22
#
# 1. How much total salary cost has increased from year 2011 to 2014?
# 2. Who was the top-earning employee across all the years?
#
# Objective: Perform data manipulation and visualization techniques.

# %%
salary = pd.read_csv("C:\\Users\\shiva\\Downloads\\Lesson 3 Practice\\Lesson 3 Practice\\Salaries.csv")

# %%
salary.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
salary['TotalPayBenefits'].sum()
# Out:
# 13927541114.140001

# %%
salary[salary['Year']==2011]['TotalPayBenefits'].sum()
# Out:
# 2594113030.72

# %%
salary[salary['Year']==2014]['TotalPayBenefits'].sum()
# Out:
# 3821865780.6

# %%
salary[salary['Year']==2014]['TotalPayBenefits'].sum()-salary[salary['Year']==2011]['TotalPayBenefits'].sum()
# Out:
# 1227752749.88

# %%
a = salary['TotalPayBenefits'].max()

# %%
salary[salary['TotalPayBenefits']==a]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %% [markdown]
# # 3.25
#
# # Practise Project

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, ".", "."],
        'postTestScore': ["25,000", "94,000", 57, 62, 70]}

# %%
df = pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# ## Save the data frame into a .csv file as project.csv
# ## Read the project.csv file and print the data frame.

# %%
df.to_csv('project.csv') # conveting existing df to csv file

# %%
df = pd.read_csv('project.csv')
df
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore postTestScore
# 0           0      Jason    Miller   42            4        25,000
# 1           1      Molly  Jacobson   52           24        94,000
# 2           2       Tina         .   36           31            57
# 3           3       Jake    Milner   24            .            62
# 4           4        Amy     Cooze   73            .            70

# %% [markdown]
# ### Read the project.csv file without column heading.

# %%
df = pd.read_csv('project.csv', header= None)
df
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70

# %% [markdown]
# ### Read the project.csv file and make two index columns, namely, ‘First Name’ and ‘Last Name’.

# %%
df = pd.read_csv('project.csv', index_col= ['First Name', 'Last Name'], names= ['UID', 'First Name', 'Last Name', 'Age', 'Pre-Test Score', 'Post-Test Score'] )
df
# Out:
#                       UID  Age Pre-Test Score Post-Test Score
# First Name Last Name
# first_name last_name  NaN  age   preTestScore   postTestScore
# Jason      Miller     0.0   42              4          25,000
# Molly      Jacobson   1.0   52             24          94,000
# Tina       .          2.0   36             31              57
# Jake       Milner     3.0   24              .              62
# Amy        Cooze      4.0   73              .              70

# %% [markdown]
# ### Print the data frame in a Boolean form as True or False. True for Null/ NaN values and false for non-null values.

# %%
df = pd.read_csv('project.csv', na_values= '.')
pd.isnull(df)
# Out:
#    Unnamed: 0  first_name  last_name    age  preTestScore  postTestScore
# 0       False       False      False  False         False          False
# 1       False       False      False  False         False          False
# 2       False       False       True  False         False          False
# 3       False       False      False  False          True          False
# 4       False       False      False  False          True          False

# %%
df.isnull()
# Out:
#    Unnamed: 0  first_name  last_name    age  preTestScore  postTestScore
# 0       False       False      False  False         False          False
# 1       False       False      False  False         False          False
# 2       False       False       True  False         False          False
# 3       False       False      False  False          True          False
# 4       False       False      False  False          True          False

# %% [markdown]
# ### Read the data frame by skipping the first 3 rows and print the data frame.

# %%
df = pd.read_csv('project.csv', skiprows= 3, header= None)
df
# Out:
#    0     1       2   3   4   5
# 0  2  Tina       .  36  31  57
# 1  3  Jake  Milner  24   .  62
# 2  4   Amy   Cooze  73   .  70

# %%
print(df)
# Out:
#    0     1       2   3   4   5
# 0  2  Tina       .  36  31  57
# 1  3  Jake  Milner  24   .  62
# 2  4   Amy   Cooze  73   .  70

# %% [markdown]
# # 5.10  (PCA)
# ### Practise Project

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
digit = load_digits()

# %%
print(digit.data)
print(digit.target)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]

# %%
x= digit.data
y= digit.target
print(y)
# Out:
# [0 1 2 ... 8 9 8]

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state= 1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
# Out:
# (1437, 64)
# (360, 64)
# (1437,)

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
predict= lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(predict, y_test)
print(accuracy)
# Out:
# 0.9694444444444444

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components= 0.95)

# %%
pca.fit(x_train)
# Out:
# PCA(n_components=0.95)

# %%
x_train_transform= pca.transform(x_train)
x_test_transform= pca.transform(x_test)

# %%
print(x_train_transform.shape)
print(x_test_transform.shape)
# Out:
# (1437, 28)
# (360, 28)

# %%
lr.fit(x_train_transform, y_train)
# Out:
# LogisticRegression()

# %%
predict= lr.predict(x_test_transform)
accuracy= accuracy_score(predict, y_test)
print(accuracy)
# Out:
# 0.975

# %% [markdown]
# # 5.15 (LDA)

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# ...

# %%
from mlxtend.data import iris_data

from mlxtend.preprocessing import standardize
from mlxtend.feature_extraction import LinearDiscriminantAnalysis

# %%
X, Y= iris_data()

# %%
X= standardize(X)

# %%
lda= LinearDiscriminantAnalysis(n_discriminants=2)

# %%
lda.fit(X, Y)
